# %%
import zipfile

import os

import pandas as pd
import numpy as np

import datetime

import re

import nltk

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4') # uses Multilingual Wordnet Data from OMW with newer Wordnet versions
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
from textblob import TextBlob # to use .correct() method to correct spellings

# %%
# %%time

with zipfile.ZipFile('../data/txt_reviews.zip') as zip_ref:
    zip_ref.extractall('../data/')
# Out:
# CPU times: user 42.3 s, sys: 2min 11s, total: 2min 54s
# Wall time: 6min 36s

# %%
files = [f'../data/txt_reviews/{x}' for x in os.listdir('../data/txt_reviews')]

# %%
# %%time

info = []

for file in files:
    with open(file, 'r') as f:
        lines = f.readlines()
        
        info.append([each_line.split(':')[1].strip() for each_line in lines])
# Out:
# CPU times: user 9.09 s, sys: 1min 12s, total: 1min 21s
# Wall time: 3min 24s

# %%
with open(files[0], 'r') as f:
    
    lines = f.readlines()
    cols = [each_line.split(':')[0] for each_line in lines]

# %%
df = pd.DataFrame(columns = cols)

# %%
df['ProductId'] = [information[0] for information in info]

df['UserId'] = [information[1] for information in info]

df['ProfileName'] = [information[2] for information in info]

df['HelpfulnessNumerator'] = [information[3] for information in info]

df['HelpfulnessDenominator'] = [information[4] for information in info]

df['Score'] = [information[5] for information in info]

df['Time'] = [information[6] for information in info]

df['ReviewSummary'] = [information[7] for information in info]

df['ReviewText'] = [information[8] for information in info]

# %%
df
# Out:
#          ProductId          UserId              ProfileName  \
# 0       B0000GHNUE  A3D7GP8AS2PRIT                     S.C.
# 1       B000TTDDWE   AA1TQ4QJ4Y94P                     barb
# 2       B0000ICLLS  A2OXNQ43JBMAEI                     nene
# 3       B000JWGFQC  A2N9T4CS40KDJE  D. Wilson "Euro writer"
# 4       B000KFXEYE  A2M9ANEOKBVD2D              Vinegar Jim
# ...            ...             ...                      ...
# 568449  B000A0WLFC   A1HH7L6EJI6N0            Paul Fillmore
# 568450  B004M050W2  A3NGUULXOMWAMM                  A. Tang
# 568451  B001VNGK6I  A2RBGOWJO35P93            Marie Flowers
# 568452  B000EY5COG  A1W7CVE5I70HVI    B. Kramer "Baker Boy"
# 568453  B0017O74DE  A21KWN4NVNHA7M                       Di
#
#        HelpfulnessNumerator HelpfulnessDenominator Score        Time  \
# 0                         1                      1     5  1268611200
# 1                         0                      0     5  1267660800
# 2                         0                      0     5  1341619200
# 3                         1                      1     3  1189209600
# 4                         3                      9     1  1291075200
# ...                     ...                    ...   ...         ...
# 568449                    4                      5     4  1230940800
# 568450                    3                      4     5  1302393600
# 568451                    8                      9     4  1310601600
# 568452                    3                      4     5  1196294400
# 568453                    1                      1     4  1340323200
#
#                                      ReviewSummary  \
# 0                          Hot but still flavorful
# 1                                            Yummy
# 2                                            candy
# 3       The muffins were a pleasant low carb treat
# 4                      Surprise...bait and switch.
# ...                                            ...
# 568449                                  Great gift
# 568450                           Excellent product
# 568451           How Curcumin is Absorbed Properly
# 568452                                  Good Stuff
# 568453                     organic sunflower seeds
#
#                                                ReviewText
# 0       We had the Green Chile Habanero one at a local...
# 1       I bought this item at Costco at Christmas time...
# 2       This is the best candy that I have ever had an...
# 3       As the subject said the muffins were a pleasan...
# 4       The company does not operate properly I ordere...
# ...                                                   ...
# 568449  I received this as a gift for xmas of 2007 and...
# 568450  I was given a bottle from a friend.  Tasted an...
# 568451  I bought some of Frontier's organic tumeric at...
# 568452  Honestly I prefer the powder-version of this p...
# 568453  It is wonderful to be able to find organic sun...
#
# [568454 rows x 9 columns]

# %%
df.dropna(inplace= True)

# %%
df.shape
# Out:
# (568454, 9)

# %%
df.drop_duplicates(inplace= True)
df.shape
# Out:
# (568167, 9)

# %% [markdown]
# ## Splitting into train and test

# %%
X = df[[x for x in df.columns if x != 'Score']]
y = df['Score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 100, stratify= y)

# %%
X_train
# Out:
#          ProductId          UserId                    ProfileName  \
# 297536  B0041FWCYM  A2ZWGWU97T6K3M                            phi
# 309715  B004JRKEH4  A12O5SEIF162P8  William A. Nolan "freeholder"
# 548765  B0013A0QXC  A34OZ261SP7CU9                Earl D. Wallace
# 63672   B000FFRU3U   AYDE7GGEGO9QQ          Rosemary P. Mcpharlin
# 458398  B003TOES7K   APOODDMKAG57Y                         marcia
# ...            ...             ...                            ...
# 150122  B003M5TG28  A14VQRIH3FDX5K                     kittenkatt
# 51681   B001ELL4E0  A2Q5YH8827Z3VS                Mary L Levesque
# 118004  B000084E6V  A37FHDFU0H1G5J                    Jaimi DeFeo
# 129611  B001FA1E7M  A2P0254ZZ42ZOJ                  Roni Kauffman
# 284895  B000CQIDK6  A3BPAT6CWRJOY5                  Blue Bohemian
#
#        HelpfulnessNumerator HelpfulnessDenominator        Time  \
# 297536                    1                      1  1343001600
# 309715                    0                      0  1314230400
# 548765                    0                      0  1348617600
# 63672                     0                      0  1315699200
# 458398                    0                      0  1322179200
# ...                     ...                    ...         ...
# 150122                    5                      6  1309910400
# 51681                     2                      2  1316131200
# 118004                    6                      7  1288656000
# 129611                    0                      2  1306281600
# 284895                    5                      5  1155686400
#
#                                    ReviewSummary  \
# 297536                    I love this seasoning!
# 309715                               Good flavor
# 548765                              Senso coffee
# 63672        healthful, not too sweet hot cereal
# 458398                                    Keurig
# ...                                          ...
# 150122  Sickening filler ingredients, high price
# 51681       Just as good or better than McCann's
# 118004          Nylabone Durable Dental Dinosaur
# 129611                         no free shipping?
# 284895                          The Best Chai...
#
#                                                ReviewText
# 297536  I love this seasoning! I use it with a slight ...
# 309715  I used this on a London broil I had grilled, a...
# 548765  I have purchased this product many times over....
# 63672   This cereal has great texture (not over-proces...
# 458398  I love my new Keurig and am very happy to have...
# ...                                                   ...
# 150122  I think the ingredients in this food speak for...
# 51681   I'm eating a bowl of it right now, and it is g...
# 118004  My dogs had this chewed apart in the matter of...
# 129611  I love these and they used to be such great va...
# 284895  I love this tea! Not only because it is organi...
#
# [454533 rows x 8 columns]

# %%
y_train
# Out:
# 297536    5
# 309715    4
# 548765    5
# 63672     4
# 458398    5
#          ..
# 150122    1
# 51681     5
# 118004    1
# 129611    4
# 284895    5
# Name: Score, Length: 454533, dtype: object

# %%
df['Score'].value_counts(normalize= True)
# Out:
# Score
# 5    0.638773
# 4    0.141907
# 1    0.091929
# 3    0.075003
# 2    0.052388
# Name: proportion, dtype: float64

# %%
y_train.value_counts(normalize= True)
# Out:
# Score
# 5    0.638774
# 4    0.141906
# 1    0.091930
# 3    0.075002
# 2    0.052388
# Name: proportion, dtype: float64

# %% [markdown]
# ### Creating a function to clean X

# %%
def clean_X(X): 
    
    X.drop(['ProductId', 'UserId', 'ProfileName', 'Time', 'HelpfulnessNumerator', 'HelpfulnessDenominator'], axis = 1, inplace = True)

    return X

# %% [markdown]
# ### Creating a function to clean y

# %%
def clean_y(y):
    y_clean = []
    
    for score in y:
        if score in ['1', '2']:
            y_clean.append('bad')
        elif score == '3':
            y_clean.append('neutral')
        else:
            y_clean.append('good')
            
    return pd.Series(y_clean, name= 'score')

# %% [markdown]
# ## Creating a function to preprocess the data

# %%
# initialization
stemmer = PorterStemmer()

# %%
# initialization
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text, flag):
    
    #1. Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", text)
    
    #2. Converting to lowercase
    sentence_1 = sentence.lower()
    
    #3. Tokenization (Word-level)
    tokens = sentence_1.split()
    
    #3.1. TextBlob- Correcting the spellings
    tokens_correct_spell = [str(TextBlob(token)) for token in tokens]

    #4. Removing stopwords
    clean_tokens = [token for token in tokens_correct_spell if token not in stopwords.words("english")]

    #5. lemmatization
    if(flag == 'stem'):
        clean_tokens_final = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens_final = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens_final), len(clean_tokens_final)])

# %% [markdown]
# # 1. Train data

# %% [markdown]
# ## 1.1.1. Cleaning X_train

# %%
# %%time

X_train = clean_X(X_train)
X_train
# Out:
# CPU times: user 36.8 ms, sys: 9.13 ms, total: 45.9 ms
# Wall time: 59.8 ms
#                                    ReviewSummary  \
# 297536                    I love this seasoning!
# 309715                               Good flavor
# 548765                              Senso coffee
# 63672        healthful, not too sweet hot cereal
# 458398                                    Keurig
# ...                                          ...
# 150122  Sickening filler ingredients, high price
# 51681       Just as good or better than McCann's
# 118004          Nylabone Durable Dental Dinosaur
# 129611                         no free shipping?
# 284895                          The Best Chai...
#
#                                                ReviewText
# 297536  I love this seasoning! I use it with a slight ...
# 309715  I used this on a London broil I had grilled, a...
# 548765  I have purchased this product many times over....
# 63672   This cereal has great texture (not over-proces...
# 458398  I love my new Keurig and am very happy to have...
# ...                                                   ...
# 150122  I think the ingredients in this food speak for...
# 51681   I'm eating a bowl of it right now, and it is g...
# 118004  My dogs had this chewed apart in the matter of...
# 129611  I love these and they used to be such great va...
# 284895  I love this tea! Not only because it is organi...
#
# [454533 rows x 2 columns]

# %% [markdown]
# ## 1.1.2. Cleaning y_train

# %%
y_train = clean_y(y_train)
y_train
# Out:
# 0         good
# 1         good
# 2         good
# 3         good
# 4         good
#           ...
# 454528     bad
# 454529    good
# 454530     bad
# 454531    good
# 454532    good
# Name: score, Length: 454533, dtype: object

# %% [markdown]
# ## 1.2 Preprocessing X_train

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
temp_df_1 = X_train['ReviewSummary'].progress_apply(lambda x: preprocess(x, 'lemma'))
temp_df_1.columns = ['revsum_clean_text_lemma', 'revsum_text_length_lemma']
# Out:
# 100%|█████████████████████████████████| 454533/454533 [02:23<00:00, 3159.95it/s]

# %%
temp_df_2 = X_train['ReviewText'].progress_apply(lambda x: preprocess(x, 'lemma'))
temp_df_2.columns = ['revtext_clean_text_lemma', 'revtext_text_length_lemma']
# Out:
# 100%|██████████████████████████████████| 454533/454533 [39:34<00:00, 191.42it/s]

# %%
temp_df = pd.concat([temp_df_1, temp_df_2], axis = 1)
temp_df
# Out:
#                        revsum_clean_text_lemma  revsum_text_length_lemma  \
# 297536                          love seasoning                         2
# 309715                             good flavor                         2
# 548765                            senso coffee                         2
# 63672               healthful sweet hot cereal                         4
# 458398                                  keurig                         1
# ...                                        ...                       ...
# 150122  sickening filler ingredient high price                         5
# 51681                       good better mccann                         3
# 118004        nylabone durable dental dinosaur                         4
# 129611                           free shipping                         2
# 284895                               best chai                         2
#
#                                  revtext_clean_text_lemma  \
# 297536  love seasoning use slight butter spray asparag...
# 309715  used london broil grilled complemented meat we...
# 548765  purchased product many time although cost rise...
# 63672   cereal great texture processed portion size ge...
# 458398  love new keurig happy found place order k cup ...
# ...                                                   ...
# 150122  think ingredient food speak cheap filler bypro...
# 51681   eating bowl right great actually like better m...
# 118004  dog chewed apart matter minute eating small pa...
# 129611  love used great value amazon happened free shi...
# 284895  love tea organic also health benefit another v...
#
#         revtext_text_length_lemma
# 297536                         21
# 309715                         24
# 548765                         12
# 63672                          34
# 458398                         17
# ...                           ...
# 150122                         35
# 51681                          31
# 118004                         11
# 129611                         12
# 284895                         46
#
# [454533 rows x 4 columns]

# %%
X_train.drop(columns= ['ReviewSummary', 'ReviewText'], inplace = True)

# %%
X_train = pd.concat([X_train, temp_df], axis = 1)
X_train
# Out:
#                        revsum_clean_text_lemma  revsum_text_length_lemma  \
# 297536                          love seasoning                         2
# 309715                             good flavor                         2
# 548765                            senso coffee                         2
# 63672               healthful sweet hot cereal                         4
# 458398                                  keurig                         1
# ...                                        ...                       ...
# 150122  sickening filler ingredient high price                         5
# 51681                       good better mccann                         3
# 118004        nylabone durable dental dinosaur                         4
# 129611                           free shipping                         2
# 284895                               best chai                         2
#
#                                  revtext_clean_text_lemma  \
# 297536  love seasoning use slight butter spray asparag...
# 309715  used london broil grilled complemented meat we...
# 548765  purchased product many time although cost rise...
# 63672   cereal great texture processed portion size ge...
# 458398  love new keurig happy found place order k cup ...
# ...                                                   ...
# 150122  think ingredient food speak cheap filler bypro...
# 51681   eating bowl right great actually like better m...
# 118004  dog chewed apart matter minute eating small pa...
# 129611  love used great value amazon happened free shi...
# 284895  love tea organic also health benefit another v...
#
#         revtext_text_length_lemma
# 297536                         21
# 309715                         24
# 548765                         12
# 63672                          34
# 458398                         17
# ...                           ...
# 150122                         35
# 51681                          31
# 118004                         11
# 129611                         12
# 284895                         46
#
# [454533 rows x 4 columns]

# %% [markdown]
# ## 1.3 Data Transformation

# %% [markdown]
# ### 1.3.1 Bag of Words approach

# %% [markdown]
# #### Just considering revtext and not revsum

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initializing the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.
vocab = CountVectorizer()

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.

X_train_bow = vocab.fit_transform(X_train['revtext_clean_text_lemma'])

# %% [markdown]
# #### Unique Words

# %%
# We can look at unique words by using 'vocabulary_'

vocab.vocabulary_
# Out:
# {'love': 42869,
#  'seasoning': 64713,
#  'use': 78163,
#  'slight': 67059,
#  'butter': 9895,
#  'spray': 69023,
#  'asparagus': 4297,
#  'grill': 31996,
#  'steamer': 69726,
#  'bag': 5343,
#  'frozen': 29110,
#  'veggie': 78742,
#  'brings': 9066,
#  'flavor': 27577,
#  'everything': 25093,
#  'without': 81480,
#  'overwhelming': 52347,
#  'change': 12084,
#  'way': 80265,
#  'cook': 16044,
#  'used': 78169,
#  'london': 42582,
#  'broil': 9171,
#  'grilled': 32000,
#  'complemented': 14962,
#  'meat': 45032,
#  'well': 80525,
#  'many': 44148,
#  'wonder': 81642,
#  'hot': 34992,
#  'tough': 75121,
#  'question': 58673,
#  'since': 66575,
#  'really': 59509,
#  'like': 41935,
#  'pepper': 53915,
#  'kind': 39909,
#  'would': 81922,
#  'call': 10353,
#  'pretty': 56966,
#  'mild': 46023,
#  'taste': 72742,
#  'may': 44772,
#  'vary': 78590,
#  'purchased': 58186,
#  'product': 57355,
#  'time': 74366,
#  'although': 2288,
#  'cost': 16419,
#  'risen': 62206,
#  'find': 27140,
#  'still': 69948,
#  'good': 31188,
#  'brand': 8709,
#  'coffee': 14276,
#  'cereal': 11833,
#  'great': 31809,
#  'texture': 73540,
#  'processed': 57275,
#  'portion': 56132,
#  'size': 66748,
#  'generous': 30129,
#  'also': 2226,
#  'overly': 52166,
#  'sweetened': 71921,
#  'fruit': 29155,
#  'became': 6214,
#  'aware': 5008,
#  'workplace': 81835,
#  'cafeteria': 10158,
#  'unfortunately': 77242,
#  'ordered': 51441,
#  'peach': 53560,
#  'raspberry': 59222,
#  'oatmeal': 50276,
#  'online': 51064,
#  'sent': 65133,
#  'onion': 51061,
#  'soup': 68316,
#  'instead': 37350,
#  'food': 28113,
#  'item': 38174,
#  'returnable': 61702,
#  'stuck': 70517,
#  'something': 68058,
#  'order': 51436,
#  'new': 48977,
#  'keurig': 39728,
#  'happy': 33129,
#  'found': 28472,
#  'place': 55236,
#  'cup': 17606,
#  'lower': 42933,
#  'price': 57038,
#  'store': 70157,
#  'arrived': 4043,
#  'quickly': 58709,
#  'perfect': 54034,
#  'condition': 15245,
#  'nice': 49104,
#  'bubbly': 9407,
#  'beverage': 6904,
#  'satisfy': 63785,
#  'desire': 19652,
#  'soda': 67811,
#  'lol': 42543,
#  'yummy': 82911,
#  'though': 74033,
#  'rice': 61962,
#  'crispy': 17129,
#  'bar': 5653,
#  'made': 43451,
#  'chocolate': 13028,
#  'wax': 80256,
#  'might': 45970,
#  'wow': 81955,
#  'treat': 75503,
#  'coated': 14111,
#  'lot': 42806,
#  'candy': 10589,
#  'cookie': 16054,
#  'problem': 57231,
#  'wanted': 80004,
#  'summer': 71148,
#  'feel': 26655,
#  'sure': 71563,
#  'melted': 45336,
#  'wonderful': 81658,
#  'crunchiness': 17351,
#  'sell': 64966,
#  'date': 18198,
#  'full': 29354,
#  'month': 47128,
#  'today': 74653,
#  'pleased': 55411,
#  'freshness': 28873,
#  'think': 73914,
#  'last': 41075,
#  'long': 42589,
#  'house': 35060,
#  'fresh': 28845,
#  'packed': 52531,
#  'arrive': 4042,
#  'crumbled': 17308,
#  'damaged': 18015,
#  'cooky': 16083,
#  'crunchy': 17362,
#  'delicious': 19078,
#  'perhaps': 54085,
#  'worst': 81882,
#  'timothy': 74409,
#  'literally': 42246,
#  'closely': 13945,
#  'remotely': 60922,
#  'resemble': 61299,
#  'kahlua': 39264,
#  'bitter': 7390,
#  'aromatic': 3982,
#  'sadly': 63182,
#  'nothing': 49698,
#  'live': 42295,
#  'reputation': 61206,
#  'comparison': 14866,
#  'low': 42919,
#  'fat': 26425,
#  'chip': 12821,
#  'best': 6809,
#  'tasted': 72748,
#  'none': 49441,
#  'wait': 79857,
#  'til': 74334,
#  'sold': 67925,
#  'local': 42446,
#  'awesome': 5033,
#  'lipton': 42157,
#  'natural': 48479,
#  'artificial': 4120,
#  'coloring': 14554,
#  'reason': 59561,
#  'felt': 26716,
#  'need': 48680,
#  'add': 761,
#  'red': 60053,
#  'see': 64827,
#  'mix': 46583,
#  'necessary': 48646,
#  'bought': 8467,
#  'saw': 63943,
#  'image': 35965,
#  'assumed': 4428,
#  'paying': 53489,
#  'fair': 26099,
#  'le': 41300,
#  'per': 53971,
#  'grocery': 32109,
#  'grade': 31477,
#  'cat': 11410,
#  'combination': 14627,
#  'led': 41419,
#  'lb': 41280,
#  'deal': 18363,
#  'received': 59731,
#  'six': 66734,
#  'thought': 74037,
#  'mistake': 46514,
#  'nope': 49569,
#  'spend': 68697,
#  'returning': 61705,
#  'three': 74077,
#  'pack': 52506,
#  'oops': 51188,
#  'ozbo': 52446,
#  'customer': 17755,
#  'service': 65281,
#  'tell': 73177,
#  'take': 72386,
#  'week': 80398,
#  'processing': 57279,
#  'return': 61701,
#  'kitty': 40050,
#  'people': 53869,
#  'want': 80001,
#  'sit': 66699,
#  'buy': 9971,
#  'scammer': 64025,
#  'health': 33596,
#  'decided': 18539,
#  'kick': 39805,
#  'habit': 32701,
#  'stumbled': 70554,
#  'upon': 78030,
#  'teeccino': 73097,
#  'herbal': 33984,
#  'medium': 45158,
#  'roast': 62329,
#  'hazelnut': 33496,
#  'heaven': 33739,
#  'exactly': 25205,
#  'easily': 22723,
#  'substitute': 70819,
#  'added': 773,
#  'brown': 9247,
#  'sugar': 71005,
#  'bailey': 5405,
#  'irish': 37929,
#  'creamer': 16921,
#  'thoroughly': 74024,
#  'enjoyed': 24054,
#  'every': 25057,
#  'sip': 66645,
#  'regular': 60521,
#  'whatsoever': 80715,
#  'try': 75935,
#  'alone': 2160,
#  'must': 48002,
#  'say': 63955,
#  'looking': 42657,
#  'forward': 28436,
#  'trying': 75944,
#  'even': 24991,
#  'herb': 33981,
#  'nut': 49992,
#  'hardly': 33201,
#  'go': 31005,
#  'wrong': 82066,
#  'cinnamon': 13495,
#  'energy': 23952,
#  'drink': 22109,
#  'one': 51023,
#  'hell': 33873,
#  'mixed': 46588,
#  'san': 63512,
#  'francisco': 28589,
#  'bay': 6008,
#  'fog': 28003,
#  'chaser': 12226,
#  'provide': 57759,
#  'decent': 18522,
#  'bold': 8060,
#  'phenomenal': 54567,
#  'half': 32861,
#  'common': 14779,
#  'competitor': 14928,
#  'worth': 81888,
#  'ordering': 51452,
#  'else': 23487,
#  'next': 49045,
#  'bet': 6833,
#  'satisfied': 63776,
#  'recommend': 59915,
#  'buying': 9977,
#  'large': 41019,
#  'quantity': 58577,
#  'extremely': 25895,
#  'sweet': 71907,
#  'caution': 11552,
#  'pleasantly': 55405,
#  'surprised': 71633,
#  'coconut': 14216,
#  'water': 80166,
#  'definitely': 18839,
#  'saturated': 63821,
#  'light': 41871,
#  'workout': 81834,
#  'whenever': 80789,
#  'throat': 74110,
#  'dry': 22254,
#  'instantly': 37346,
#  'remove': 60931,
#  'feeling': 26660,
#  'mouth': 47500,
#  'br': 8629,
#  'can': 10523,
#  'bit': 7371,
#  'dented': 19371,
#  'single': 66607,
#  'luckily': 43043,
#  'open': 51224,
#  'dent': 19352,
#  'affected': 1192,
#  'inside': 37272,
#  'graham': 31504,
#  'cracker': 16732,
#  'packaging': 52526,
#  'idea': 35770,
#  'high': 34197,
#  'five': 27366,
#  'honey': 34724,
#  'maid': 43603,
#  'remains': 60820,
#  'advantage': 1029,
#  'disadvantage': 20613,
#  'smaller': 67262,
#  'sized': 66751,
#  'stack': 69398,
#  'know': 40199,
#  'box': 8571,
#  'get': 30292,
#  'bunch': 9653,
#  'finish': 27191,
#  'sitting': 66720,
#  'often': 50719,
#  'stale': 69453,
#  'back': 5225,
#  'another': 3074,
#  'day': 18271,
#  'halved': 32927,
#  'hungry': 35383,
#  'eater': 22767,
#  'leaving': 41387,
#  'opened': 51228,
#  'thing': 73902,
#  'past': 53282,
#  'sometimes': 68064,
#  'two': 76337,
#  'stuff': 70535,
#  'em': 23506,
#  'coat': 14110,
#  'pocket': 55597,
#  'purse': 58322,
#  'snack': 67486,
#  'inch': 36397,
#  'away': 5013,
#  'brittle': 9120,
#  'shipped': 65842,
#  'chance': 12072,
#  'break': 8821,
#  'fall': 26156,
#  'apart': 3335,
#  'arriving': 4047,
#  'arm': 3926,
#  'going': 31090,
#  'look': 42644,
#  'eat': 22757,
#  'quick': 58694,
#  'expiration': 25674,
#  'awhile': 5047,
#  'enjoy': 24050,
#  'potato': 56265,
#  'russet': 63029,
#  'hardy': 33217,
#  'fit': 27345,
#  'description': 19587,
#  'tee': 73093,
#  'honestly': 34719,
#  'never': 48967,
#  'million': 46101,
#  'year': 82431,
#  'work': 81811,
#  'using': 78200,
#  'shampoo': 65502,
#  'conditioner': 15249,
#  'lazartigue': 41265,
#  'kiehls': 39847,
#  'always': 2339,
#  'itchy': 38168,
#  'scalp': 64016,
#  'dandruff': 18068,
#  'run': 62966,
#  'vine': 79258,
#  'program': 57441,
#  'ramen': 59063,
#  'hand': 32981,
#  'noodle': 49526,
#  'bigger': 7069,
#  'better': 6862,
#  'broth': 9233,
#  'flavoring': 27605,
#  'top': 74912,
#  'maruchan': 44480,
#  'pricier': 57056,
#  'eating': 22780,
#  'meal': 44982,
#  'boiling': 8043,
#  'stir': 70006,
#  'fry': 29246,
#  'whatever': 80700,
#  'kimchi': 39902,
#  'far': 26316,
#  'tried': 75667,
#  'sale': 63312,
#  'whim': 80860,
#  'knowing': 40203,
#  'boy': 8590,
#  'come': 14644,
#  'brick': 8988,
#  'circular': 13543,
#  'breaking': 8845,
#  'square': 69183,
#  'small': 67260,
#  'pan': 52789,
#  'packet': 52542,
#  'vegetable': 78714,
#  'entire': 24213,
#  'fact': 26042,
#  'tasting': 72788,
#  'weak': 80298,
#  'greatly': 31825,
#  'reducing': 60169,
#  'sodium': 67831,
#  'intake': 37434,
#  'spicy': 68760,
#  'side': 66287,
#  'cabbage': 10064,
#  'rubbed': 62858,
#  'chili': 12745,
#  'powder': 56377,
#  'pickled': 54812,
#  'bowl': 8555,
#  'foil': 28025,
#  'package': 52515,
#  'asian': 4254,
#  'grocer': 32102,
#  'wally': 79949,
#  'world': 81845,
#  'carry': 11248,
#  'styrofoam': 70625,
#  'around': 4000,
#  'buck': 9429,
#  'vial': 79100,
#  'described': 19576,
#  'needed': 48683,
#  'pre': 56525,
#  'filled': 27072,
#  'international': 37579,
#  'flight': 27719,
#  'checked': 12318,
#  'baggage': 5355,
#  'rode': 62436,
#  'cargo': 11067,
#  'area': 3813,
#  'plane': 55268,
#  'concerned': 15156,
#  'leak': 41329,
#  'due': 22336,
#  'pressure': 56914,
#  'especially': 24659,
#  'chicago': 12642,
#  'foot': 28179,
#  'sea': 64608,
#  'level': 41676,
#  'withstood': 81487,
#  'test': 73466,
#  'leakage': 41330,
#  'twice': 76255,
#  'excellent': 25287,
#  'within': 81469,
#  'read': 59425,
#  'original': 51596,
#  'list': 42215,
#  'ingredient': 37019,
#  'available': 4875,
#  'disappointment': 20667,
#  'indeed': 36569,
#  'contain': 15717,
#  'nitrite': 49267,
#  'alright': 2219,
#  'jerky': 38672,
#  'nitrate': 49264,
#  'kept': 39649,
#  'fridge': 28914,
#  'several': 65351,
#  'mold': 46899,
#  'issue': 38112,
#  'truly': 75896,
#  'consume': 15686,
#  'little': 42283,
#  'possible': 56204,
#  'end': 23847,
#  'trashing': 75442,
#  'please': 55409,
#  'revise': 61795,
#  'accurate': 510,
#  'understanding': 77000,
#  'version': 78992,
#  'cannot': 10664,
#  'seem': 64860,
#  'amazon': 2443,
#  'barilla': 5740,
#  'whole': 80988,
#  'grain': 31513,
#  'fusilli': 29514,
#  'marinara': 44325,
#  'sauce': 63829,
#  'refrigeration': 60377,
#  'toss': 75045,
#  'kitchen': 40019,
#  'cabinet': 10076,
#  'desk': 19659,
#  'leave': 41379,
#  'briefcase': 9007,
#  'fix': 27372,
#  'taking': 72400,
#  'minute': 46315,
#  'heat': 33705,
#  'microwave': 45890,
#  'quite': 58786,
#  'tasty': 72800,
#  'nuke': 49894,
#  'scarf': 64067,
#  'fill': 27069,
#  'belly': 6537,
#  'ounce': 51821,
#  'filling': 27077,
#  'salad': 63279,
#  'bread': 8791,
#  'pasta': 53283,
#  'al': 1718,
#  'dente': 19370,
#  'chew': 12579,
#  'flavorful': 27597,
#  'calorie': 10413,
#  'healthier': 33615,
#  'keep': 39547,
#  'starbuck': 69544,
#  'much': 47632,
#  'tully': 76061,
#  'french': 28803,
#  'tastiest': 72783,
#  'label': 40687,
#  'claim': 13646,
#  'silky': 66437,
#  'smooth': 67425,
#  'hydration': 35514,
#  'infusion': 36957,
#  'electrolyte': 23350,
#  'ph': 54517,
#  'comment': 14727,
#  'scientific': 64301,
#  'equipment': 24442,
#  'wish': 81416,
#  'could': 16500,
#  'give': 30631,
#  'flowery': 27869,
#  'wine': 81306,
#  'ability': 135,
#  'smell': 67321,
#  'hint': 34334,
#  'apricot': 3663,
#  'smoke': 67378,
#  'charcoal': 12163,
#  'drinking': 22122,
#  'somehow': 68018,
#  'different': 20251,
#  'cold': 14415,
#  'room': 62584,
#  'temperature': 73217,
#  'unable': 76629,
#  'conjure': 15424,
#  'factor': 26047,
#  'difference': 20248,
#  'set': 65317,
#  'challenge': 12019,
#  'similar': 66483,
#  'old': 50849,
#  'pepsi': 53957,
#  'co': 14072,
#  'worker': 81824,
#  'follows': 28070,
#  'husband': 35440,
#  'sleepytime': 67022,
#  'night': 49170,
#  'sleep': 67005,
#  'soundly': 68312,
#  'hour': 35053,
#  'become': 6247,
#  'tradition': 75258,
#  'consuming': 15696,
#  'adding': 798,
#  'supermarket': 71355,
#  'com': 14597,
#  'believe': 6485,
#  'tea': 72946,
#  'total': 75066,
#  'right': 62093,
#  'door': 21718,
#  'save': 63898,
#  'plus': 55548,
#  'gas': 29861,
#  'unaware': 76707,
#  'factory': 26050,
#  'sealed': 64635,
#  'con': 15106,
#  'quality': 58549,
#  'value': 78447,
#  'purchase': 58185,
#  'litter': 42272,
#  'starting': 69612,
#  'oil': 50777,
#  'garage': 29772,
#  'pearl': 53602,
#  'ultimate': 76566,
#  'scent': 64117,
#  'mess': 45573,
#  'track': 75229,
#  'solution': 67993,
#  'job': 38823,
#  'dont': 21678,
#  'economical': 22889,
#  'scoopaway': 64352,
#  'subscribed': 70736,
#  'bimonthly': 7165,
#  'shipment': 65835,
#  'convenience': 15944,
#  'chipped': 12839,
#  'front': 29060,
#  'bottom': 8437,
#  'teeth': 73123,
#  'went': 80569,
#  'handful': 32998,
#  'scrambled': 64443,
#  'egg': 23158,
#  'sulfer': 71098,
#  'yeah': 82425,
#  'till': 74342,
#  'mostly': 47369,
#  'drinker': 22117,
#  'occasionally': 50456,
#  'instant': 37340,
#  'provides': 57764,
#  'ten': 73254,
#  'cal': 10263,
#  'oz': 52442,
#  'sucralose': 70935,
#  'glad': 30668,
#  'leaf': 41313,
#  'decaf': 18443,
#  'green': 31865,
#  'strawberry': 70294,
#  'acai': 350,
#  'put': 58355,
#  'bottled': 8426,
#  'home': 34617,
#  'glass': 30695,
#  'couple': 16576,
#  'boast': 7938,
#  'real': 59461,
#  'winner': 81339,
#  'nasty': 48419,
#  'absolutely': 265,
#  'loved': 42872,
#  'free': 28732,
#  'sample': 63493,
#  'search': 64667,
#  'big': 7049,
#  'bland': 7540,
#  'salty': 63412,
#  'rasins': 59217,
#  'book': 8218,
#  'daughter': 18219,
#  'done': 21652,
#  'website': 80365,
#  'shop': 65981,
#  'probably': 57198,
#  'vanilla': 78484,
#  'bean': 6114,
#  'shrink': 66140,
#  'wrapped': 81993,
#  'wonderfully': 81666,
#  'fragrant': 28554,
#  'seller': 64975,
#  'earlier': 22659,
#  'expected': 25574,
#  'custard': 17744,
#  'huge': 35236,
#  'extract': 25857,
#  'making': 43721,
#  'split': 68897,
#  'vodka': 79544,
#  'hard': 33174,
#  'internet': 37587,
#  'charge': 12173,
#  'usually': 78229,
#  'merchant': 45483,
#  'thanks': 73609,
#  'depend': 19423,
#  'everyday': 25064,
#  'awful': 5041,
#  'repeat': 61053,
#  'usage': 78154,
#  'chemical': 12473,
#  'plain': 55253,
#  'simple': 66529,
#  'caffeine': 10178,
#  'jittery': 38785,
#  'unsettled': 77761,
#  'sleeping': 67012,
#  'friend': 28928,
#  'mine': 46177,
#  'frankly': 28627,
#  'left': 41446,
#  'enough': 24100,
#  'drank': 21992,
#  'caffeinated': 10172,
#  'heart': 33667,
#  'attack': 4613,
#  'threw': 74086,
#  'first': 27289,
#  'vacation': 78314,
#  'risky': 62217,
#  'surprise': 71632,
#  'baby': 5177,
#  'mths': 47620,
#  'smelled': 67322,
#  'gobbled': 31024,
#  'definate': 18798,
#  'signed': 66365,
#  'regularly': 60527,
#  'delivery': 19182,
#  'monthly': 47131,
#  'dad': 17933,
#  'watch': 80149,
#  'feral': 26762,
#  'colony': 14536,
#  'dozen': 21938,
#  'given': 30634,
#  'donates': 21642,
#  'capturing': 10862,
#  'medical': 45102,
#  'attention': 4645,
#  'fixed': 27379,
#  'spends': 68703,
#  'money': 47012,
#  'state': 69644,
#  'lend': 41551,
#  'canned': 10641,
#  'support': 71482,
#  'cause': 11545,
#  'normally': 49602,
#  'miss': 46483,
#  'wet': 80633,
#  'make': 43694,
#  'easier': 22718,
#  'catch': 11441,
#  'turn': 76160,
#  'treated': 75507,
#  'spayed': 68558,
#  'important': 36213,
#  'keeping': 39550,
#  'healthy': 33633,
#  'doritos': 21758,
#  'stock': 70038,
#  'heavy': 33752,
#  'catfood': 11469,
#  'car': 10875,
#  'pantry': 52902,
#  'subscription': 70748,
#  'prime': 57100,
#  'shipping': 65851,
#  'quarterly': 58594,
#  'middle': 45907,
#  'road': 62303,
#  'hamburger': 32944,
#  'helper': 33899,
#  'salisbury': 63338,
#  'steak': 69708,
#  'gravy': 31757,
#  'ground': 32169,
#  'turkey': 76147,
#  'beef': 6292,
#  'cheaper': 12285,
#  'prepare': 56792,
#  'exact': 25198,
#  'recipe': 59805,
#  'horrible': 34914,
#  'watery': 80216,
#  'almost': 2137,
#  'stage': 69421,
#  'protein': 57682,
#  'pouch': 56320,
#  'possibly': 56209,
#  'finest': 27159,
#  'ever': 25018,
#  'mellow': 45311,
#  'organic': 51520,
#  'tanted': 72568,
#  'harmful': 33250,
#  'brew': 8953,
#  'bravo': 8768,
#  'extreme': 25893,
#  'second': 64765,
#  'tryed': 75938,
#  'oolong': 51136,
#  'life': 41832,
#  'hope': 34827,
#  'earl': 22655,
#  'grey': 31962,
#  'essentially': 24718,
#  'carefully': 11045,
#  'selected': 64940,
#  'blend': 7647,
#  'black': 7450,
#  'italian': 38142,
#  'bergamot': 6709,
#  'orange': 51393,
#  'flavored': 27589,
#  'lemon': 41527,
#  'color': 14538,
#  'brewed': 8956,
#  'result': 61567,
#  'personally': 54285,
#  'notice': 49709,
#  'sensitive': 65112,
#  'fine': 27150,
#  'healthful': 33610,
#  'anytime': 3282,
#  'worry': 81869,
#  'getting': 30307,
#  'non': 49413,
#  'came': 10461,
#  'individual': 36677,
#  'serving': 65293,
#  'stronger': 70449,
#  'strong': 70446,
#  'jar': 38487,
#  'originally': 51600,
#  'looked': 42648,
#  'breakfast': 8835,
#  'pain': 52619,
#  'starbucks': 69549,
#  'daily': 17967,
#  'highly': 34224,
#  'rom': 62511,
#  'imagine': 35975,
#  'doggie': 21505,
#  'underarm': 76910,
#  'deodorant': 19399,
#  'squeeze': 69226,
#  'roller': 62494,
#  'upside': 78054,
#  'let': 41635,
#  'dog': 21487,
#  'lick': 41766,
#  'unique': 77391,
#  'useful': 78172,
#  'training': 75294,
#  'tool': 74858,
#  'shudder': 66186,
#  'happen': 33111,
#  'tounge': 75133,
#  'rash': 59211,
#  'push': 58340,
#  'dried': 22083,
#  'spot': 68998,
#  'worse': 81874,
#  'drip': 22132,
#  'juice': 39058,
#  'saying': 63965,
#  'edit': 22989,
#  'review': 61783,
#  'giving': 30640,
#  'star': 69533,
#  'gone': 31170,
#  'terribly': 73415,
#  'terrible': 73412,
#  'changed': 12085,
#  'formula': 28361,
#  'heard': 33656,
#  'complain': 14942,
#  'talking': 72433,
#  'crazy': 16897,
#  'least': 41371,
#  'cappuchino': 10809,
#  'bad': 5311,
#  'able': 145,
#  'dissapointed': 21127,
#  'muffin': 47697,
#  'bed': 6259,
#  'owner': 52388,
#  'admit': 929,
#  'care': 11033,
#  'oven': 52005,
#  'amazing': 2428,
#  'pecan': 53627,
#  'tastier': 72781,
#  'skeptical': 66802,
#  'pretend': 56945,
#  'capp': 10773,
#  'milk': 46053,
#  'sweetner': 71955,
#  'fortune': 28423,
#  'double': 21805,
#  'boxed': 8578,
#  'packing': 52556,
#  'inner': 37168,
#  'sturdy': 70592,
#  'cardboard': 11002,
#  'broken': 9179,
#  'slightly': 67065,
#  'vanilly': 78497,
#  'noted': 49682,
#  'repacked': 61035,
#  'got': 31371,
#  'gallon': 29691,
#  'zip': 83196,
#  'lock': 42468,
#  'totally': 75078,
#  'eight': 23223,
#  'discrepancy': 20818,
#  'clearly': 13790,
#  'printed': 57136,
#  'english': 24008,
#  'chinese': 12799,
#  'word': 81798,
#  'learn': 41358,
#  'written': 82059,
#  'character': 12144,
#  'pronunciation': 57561,
#  'lucky': 43047,
#  'number': 49909,
#  'wolfgang': 81613,
#  'puck': 57923,
#  'jamaicamecrazy': 38390,
#  'partial': 53179,
#  'refund': 60396,
#  'gotten': 31384,
#  'throw': 74132,
#  'pay': 53481,
#  'response': 61450,
#  'iced': 35723,
#  'counter': 16537,
#  'cant': 10687,
#  'lunch': 43115,
#  'bring': 9061,
#  'afternoon': 1328,
#  'im': 35963,
#  'family': 26220,
#  'unconventional': 76843,
#  'classic': 13714,
#  'shake': 65464,
#  'bake': 5426,
#  'pork': 56077,
#  'chop': 13186,
#  'chicken': 12662,
#  'snb': 67581,
#  'skin': 66848,
#  'leg': 41453,
#  'thigh': 73882,
#  'placed': 55238,
#  'covered': 16651,
#  'min': 46145,
#  'uncovered': 76860,
#  'sprinkled': 69071,
#  'remaining': 60818,
#  'cooked': 16048,
#  'additional': 812,
#  'coating': 14114,
#  'stayed': 69695,
#  'delish': 19148,
#  'savor': 63926,
#  'relax': 60707,
#  'evening': 24995,
#  'rich': 61979,
#  'completely': 14970,
#  'ww': 82141,
#  'point': 55659,
#  'mean': 44995,
#  'expect': 25562,
#  'recognize': 59860,
#  'downside': 21903,
#  ...}

# %%
print("Total unique words", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words 83347
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (454533, 83347)

# %% [markdown]
# ## 2.1.1. Cleaning X_test

# %%
# %%time

X_test = clean_X(X_test)
X_test
# Out:
# CPU times: user 15.3 ms, sys: 55.4 ms, total: 70.7 ms
# Wall time: 92 ms
#                                             ReviewSummary  \
# 289270                 Works great and we will order more
# 93271                     Will not buy this product again
# 291601                                       great coffee
# 347392                              Peppers were very dry
# 261121              If you like weak tea, this is for you
# ...                                                   ...
# 397590                             A bit gritty and green
# 82608                                     Kiddo loves it!
# 343778                                   Not as described
# 297557  Very good in smoothies, but why the short shel...
# 277157                                  Good French Roast
#
#                                                ReviewText
# 289270  We are very satisfied with Natural Vitality-Na...
# 93271   The hospital where I worked bought this coffee...
# 291601  We found this k-cup coffee concept to be quick...
# 347392  The peppers were very dry because the oil came...
# 261121  This tea isn't bad, it just made (to me) a wea...
# ...                                                   ...
# 397590  I have to put this in a travel cup for my 5 ye...
# 82608   We use jar baby food to supplement what we mak...
# 343778  These are not really anchovie stuffed olives, ...
# 297557  I really like the taste of this powder.  It is...
# 277157  Tully's French Roast is a solid choice and one...
#
# [113634 rows x 2 columns]

# %% [markdown]
# ## 2.1.2. Cleaning y_teset

# %%
y_test = clean_y(y_test)
y_test
# Out:
# 0            good
# 1             bad
# 2            good
# 3             bad
# 4             bad
#            ...
# 113629    neutral
# 113630       good
# 113631        bad
# 113632    neutral
# 113633       good
# Name: score, Length: 113634, dtype: object

# %% [markdown]
# ## 2.2. Preprocessing X_test

# %%
temp_df_1 = X_test['ReviewSummary'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_1.columns = ['revsum_clean_text_stem', 'revsum_text_length_stem']
# Out:
# 100%|█████████████████████████████████| 113634/113634 [00:39<00:00, 2881.14it/s]

# %%
temp_df_2 = X_test['ReviewText'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_2.columns = ['revtext_clean_text_stem', 'revtext_text_length_stem']
# Out:
# 100%|██████████████████████████████████| 113634/113634 [12:39<00:00, 149.59it/s]

# %%
temp_df = pd.concat([temp_df_1, temp_df_2], axis = 1)
temp_df
# Out:
#                revsum_clean_text_stem  revsum_text_length_stem  \
# 289270               work great order                        3
# 93271                     buy product                        2
# 291601                    great coffe                        2
# 347392                     pepper dri                        2
# 261121                  like weak tea                        3
# ...                               ...                      ...
# 397590               bit gritti green                        3
# 82608                      kiddo love                        2
# 343778                        describ                        1
# 297557  good smoothi short shelf life                        5
# 277157              good french roast                        3
#
#                                   revtext_clean_text_stem  \
# 289270  satisfi natur vital natur calm oz powder work ...
# 93271   hospit work bought coffe singl use pack everi ...
# 291601  found k cup coffe concept quick tidi newman pu...
# 347392  pepper dri oil came box jar br would purchas item
# 261121  tea bad made weak cup use recommend pod holder...
# ...                                                   ...
# 397590  put travel cup year old els drink use smooth c...
# 82608   use jar babi food supplement make homemad some...
# 343778  realli anchovi stuf oliv littl anchovi past ne...
# 297557  realli like tast powder great protein shake es...
# 277157  tulli french roast solid choic one stapl favor...
#
#         revtext_text_length_stem
# 289270                        11
# 93271                         56
# 291601                        15
# 347392                        10
# 261121                        31
# ...                          ...
# 397590                        49
# 82608                         32
# 343778                        16
# 297557                        39
# 277157                        33
#
# [113634 rows x 4 columns]

# %%
X_test.drop(columns= ['ReviewSummary', 'ReviewText'], inplace = True)

# %%
X_test = pd.concat([X_test, temp_df], axis = 1)
X_test
# Out:
#                revsum_clean_text_stem  revsum_text_length_stem  \
# 289270               work great order                        3
# 93271                     buy product                        2
# 291601                    great coffe                        2
# 347392                     pepper dri                        2
# 261121                  like weak tea                        3
# ...                               ...                      ...
# 397590               bit gritti green                        3
# 82608                      kiddo love                        2
# 343778                        describ                        1
# 297557  good smoothi short shelf life                        5
# 277157              good french roast                        3
#
#                                   revtext_clean_text_stem  \
# 289270  satisfi natur vital natur calm oz powder work ...
# 93271   hospit work bought coffe singl use pack everi ...
# 291601  found k cup coffe concept quick tidi newman pu...
# 347392  pepper dri oil came box jar br would purchas item
# 261121  tea bad made weak cup use recommend pod holder...
# ...                                                   ...
# 397590  put travel cup year old els drink use smooth c...
# 82608   use jar babi food supplement make homemad some...
# 343778  realli anchovi stuf oliv littl anchovi past ne...
# 297557  realli like tast powder great protein shake es...
# 277157  tulli french roast solid choic one stapl favor...
#
#         revtext_text_length_stem
# 289270                        11
# 93271                         56
# 291601                        15
# 347392                        10
# 261121                        31
# ...                          ...
# 397590                        49
# 82608                         32
# 343778                        16
# 297557                        39
# 277157                        33
#
# [113634 rows x 4 columns]

# %% [markdown]
# ## 2.3 Data Transformation

# %% [markdown]
# ### Bag of Words

# %% [markdown]
# #### Just considering revtext and not revsum

# %%
X_test_bow = vocab.transform(X_test['revtext_clean_text_stem'])

# %%
print("Total unique words", len(vocab.vocabulary_))

print("Type of train features:", type(X_test_bow))
# Out:
# Total unique words 83347
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>

# %% [markdown]
# # 3. Model

# %% [markdown]
# ## Logistic Regression

# %%
X_train.shape
# Out:
# (454533, 4)

# %%
X_train_bow.shape
# Out:
# (454533, 83347)

# %%
len(y_train)
# Out:
# 454533

# %%
# %%time

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow, y_train)
# Out:
# CPU times: user 20.6 s, sys: 1.44 s, total: 22 s
# Wall time: 27.4 s
# /Users/r.shahukaru/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))
# Out:
# 0.8205026664554623
#               precision    recall  f1-score   support
#
#          bad       0.70      0.39      0.50     16399
#         good       0.85      0.96      0.90     88712
#      neutral       0.37      0.16      0.22      8523
#
#     accuracy                           0.82    113634
#    macro avg       0.64      0.50      0.54    113634
# weighted avg       0.79      0.82      0.79    113634

# %% [markdown]
# ## Decision Tree

# %%
# %%time

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_bow, y_train)

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))

# %% [markdown]
# ## Random Forest

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_bow, y_train)

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))
