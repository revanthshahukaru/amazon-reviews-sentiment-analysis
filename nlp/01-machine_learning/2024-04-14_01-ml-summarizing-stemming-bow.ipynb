# %%
import zipfile

import os

import pandas as pd
import numpy as np

import datetime

import re

import nltk

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4') # uses Multilingual Wordnet Data from OMW with newer Wordnet versions
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/r.shahukaru/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
from textblob import TextBlob # to use .correct() method to correct spellings

# %%
# %%time

with zipfile.ZipFile('../data/txt_reviews.zip') as zip_ref:
    zip_ref.extractall('../data/')
# Out:
# CPU times: user 29.8 s, sys: 1min 53s, total: 2min 23s
# Wall time: 7min 31s

# %%
files = [f'../data/txt_reviews/{x}' for x in os.listdir('../data/txt_reviews')]

# %%
# %%time

info = []

for file in files:
    with open(file, 'r') as f:
        lines = f.readlines()
        
        info.append([each_line.split(':')[1].strip() for each_line in lines])
# Out:
# CPU times: user 5.99 s, sys: 26.3 s, total: 32.3 s
# Wall time: 1min 56s

# %%
with open(files[0], 'r') as f:
    
    lines = f.readlines()
    cols = [each_line.split(':')[0] for each_line in lines]

# %%
df = pd.DataFrame(columns = cols)

# %%
df['ProductId'] = [information[0] for information in info]

df['UserId'] = [information[1] for information in info]

df['ProfileName'] = [information[2] for information in info]

df['HelpfulnessNumerator'] = [information[3] for information in info]

df['HelpfulnessDenominator'] = [information[4] for information in info]

df['Score'] = [information[5] for information in info]

df['Time'] = [information[6] for information in info]

df['ReviewSummary'] = [information[7] for information in info]

df['ReviewText'] = [information[8] for information in info]

# %%
df
# Out:
#          ProductId          UserId              ProfileName  \
# 0       B0000GHNUE  A3D7GP8AS2PRIT                     S.C.
# 1       B000TTDDWE   AA1TQ4QJ4Y94P                     barb
# 2       B0000ICLLS  A2OXNQ43JBMAEI                     nene
# 3       B000JWGFQC  A2N9T4CS40KDJE  D. Wilson "Euro writer"
# 4       B000KFXEYE  A2M9ANEOKBVD2D              Vinegar Jim
# ...            ...             ...                      ...
# 568449  B000A0WLFC   A1HH7L6EJI6N0            Paul Fillmore
# 568450  B004M050W2  A3NGUULXOMWAMM                  A. Tang
# 568451  B001VNGK6I  A2RBGOWJO35P93            Marie Flowers
# 568452  B000EY5COG  A1W7CVE5I70HVI    B. Kramer "Baker Boy"
# 568453  B0017O74DE  A21KWN4NVNHA7M                       Di
#
#        HelpfulnessNumerator HelpfulnessDenominator Score        Time  \
# 0                         1                      1     5  1268611200
# 1                         0                      0     5  1267660800
# 2                         0                      0     5  1341619200
# 3                         1                      1     3  1189209600
# 4                         3                      9     1  1291075200
# ...                     ...                    ...   ...         ...
# 568449                    4                      5     4  1230940800
# 568450                    3                      4     5  1302393600
# 568451                    8                      9     4  1310601600
# 568452                    3                      4     5  1196294400
# 568453                    1                      1     4  1340323200
#
#                                      ReviewSummary  \
# 0                          Hot but still flavorful
# 1                                            Yummy
# 2                                            candy
# 3       The muffins were a pleasant low carb treat
# 4                      Surprise...bait and switch.
# ...                                            ...
# 568449                                  Great gift
# 568450                           Excellent product
# 568451           How Curcumin is Absorbed Properly
# 568452                                  Good Stuff
# 568453                     organic sunflower seeds
#
#                                                ReviewText
# 0       We had the Green Chile Habanero one at a local...
# 1       I bought this item at Costco at Christmas time...
# 2       This is the best candy that I have ever had an...
# 3       As the subject said the muffins were a pleasan...
# 4       The company does not operate properly I ordere...
# ...                                                   ...
# 568449  I received this as a gift for xmas of 2007 and...
# 568450  I was given a bottle from a friend.  Tasted an...
# 568451  I bought some of Frontier's organic tumeric at...
# 568452  Honestly I prefer the powder-version of this p...
# 568453  It is wonderful to be able to find organic sun...
#
# [568454 rows x 9 columns]

# %%
df.dropna(inplace= True)

# %%
df.shape
# Out:
# (568454, 9)

# %%
df.drop_duplicates(inplace= True)
df.shape
# Out:
# (568167, 9)

# %% [markdown]
# ## Splitting into train and test

# %%
X = df[[x for x in df.columns if x != 'Score']]
y = df['Score']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.85, random_state = 100, stratify= y)

# %%
X_train
# Out:
#          ProductId          UserId                         ProfileName  \
# 380818  B001CU0N9K  A2FQCGYGQRQ6DR                           KathleenP
# 21338   B0051WBNG2   AIYYSXZJRYYDR                            F. Cohen
# 368711  B004NSH6O8  A3GFK7F5IUF60X         Myra Schjelderup "Ignolopi"
# 141202  B000CQID2Y   AQGZUG5IHZ9X7  Ibrahim Al-Abdulwahab "IbrahimZen"
# 180881  B003VIWN26  A2CN496XAPHDL4                              Sue M.
# ...            ...             ...                                 ...
# 150122  B003M5TG28  A14VQRIH3FDX5K                          kittenkatt
# 295370  B0049ULB78  A3C2Z6EYQQBXZV                       Shari Karanas
# 118004  B000084E6V  A37FHDFU0H1G5J                         Jaimi DeFeo
# 303837  B005K4Q37A  A367O562XAG9K9                              Goldie
# 1800    B000GFYRIK  A1UFLVSJ3IRETQ                       Eric Aderhold
#
#        HelpfulnessNumerator HelpfulnessDenominator        Time  \
# 380818                    1                      1  1300492800
# 21338                     0                      0  1349222400
# 368711                    1                      1  1320105600
# 141202                    0                      0  1308096000
# 180881                    0                      0  1302566400
# ...                     ...                    ...         ...
# 150122                    5                      6  1309910400
# 295370                    0                      0  1320451200
# 118004                    6                      7  1288656000
# 303837                    1                      1  1327363200
# 1800                      1                      1  1283904000
#
#                                             ReviewSummary  \
# 380818                 Great bang for the "caloric" buck!
# 21338                                         My Favorite
# 368711                                          New Love!
# 141202                            Very fine Chamomile tea
# 180881                 Wellness Simple Solutions Dog Food
# ...                                                   ...
# 150122           Sickening filler ingredients, high price
# 295370                                        Bold Flavor
# 118004                   Nylabone Durable Dental Dinosaur
# 303837  Pretty damn good....but I LIKE the Wawa/Conven...
# 1800                                               Tasty!
#
#                                                ReviewText
# 380818  At only 80 calories these are a great bang for...
# 21338   I sent for the tea, because I can't buy it in ...
# 368711  I absolutely love these chocolate bars! They c...
# 141202  I have been drinking this Chamomile tea for th...
# 180881  My dogs do well on Wellness Simple Solutions; ...
# ...                                                   ...
# 150122  I think the ingredients in this food speak for...
# 295370  I have tried many k-cups and this one is by fa...
# 118004  My dogs had this chewed apart in the matter of...
# 303837  First of all, let me say that I LIKE the stuff...
# 1800    This tea is really quite good. It is a quality...
#
# [482941 rows x 8 columns]

# %%
y_train
# Out:
# 380818    5
# 21338     5
# 368711    5
# 141202    5
# 180881    5
#          ..
# 150122    1
# 295370    5
# 118004    1
# 303837    4
# 1800      5
# Name: Score, Length: 482941, dtype: object

# %%
df['Score'].value_counts(normalize= True)
# Out:
# Score
# 5    0.638773
# 4    0.141907
# 1    0.091929
# 3    0.075003
# 2    0.052388
# Name: proportion, dtype: float64

# %%
y_train.value_counts(normalize= True)
# Out:
# Score
# 5    0.638774
# 4    0.141908
# 1    0.091928
# 3    0.075003
# 2    0.052387
# Name: proportion, dtype: float64

# %% [markdown]
# ### Creating a function to clean X

# %%
def clean_X(X): 
    
    X.drop(['ProductId', 'UserId', 'ProfileName', 'Time', 'HelpfulnessNumerator', 'HelpfulnessDenominator'], axis = 1, inplace = True)

    return X

# %% [markdown]
# ### Creating a function to clean y

# %%
def clean_y(y):
    y_clean = []
    
    for score in y:
        if score in ['1', '2']:
            y_clean.append('bad')
        elif score == '3':
            y_clean.append('neutral')
        else:
            y_clean.append('good')
            
    return pd.Series(y_clean, name= 'score')

# %% [markdown]
# ## Creating a function to preprocess the data

# %%
# initialization
stemmer = PorterStemmer()

# %%
# initialization
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text, flag):
    
    #1. Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", text)
    
    #2. Converting to lowercase
    sentence_1 = sentence.lower()
    
    #3. Tokenization (Word-level)
    tokens = sentence_1.split()
    
    #3.1. TextBlob- Correcting the spellings
    tokens_correct_spell = [str(TextBlob(token)) for token in tokens]

    #4. Removing stopwords
    clean_tokens = [token for token in tokens_correct_spell if token not in stopwords.words("english")]

    #5. lemmatization
    if(flag == 'stem'):
        clean_tokens_final = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens_final = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens_final), len(clean_tokens_final)])

# %% [markdown]
# # 1. Train data

# %% [markdown]
# ## 1.1.1. Cleaning X_train

# %%
# %%time

X_train = clean_X(X_train)
X_train
# Out:
# CPU times: user 31.1 ms, sys: 3.73 ms, total: 34.8 ms
# Wall time: 34.2 ms
#                                             ReviewSummary  \
# 380818                 Great bang for the "caloric" buck!
# 21338                                         My Favorite
# 368711                                          New Love!
# 141202                            Very fine Chamomile tea
# 180881                 Wellness Simple Solutions Dog Food
# ...                                                   ...
# 150122           Sickening filler ingredients, high price
# 295370                                        Bold Flavor
# 118004                   Nylabone Durable Dental Dinosaur
# 303837  Pretty damn good....but I LIKE the Wawa/Conven...
# 1800                                               Tasty!
#
#                                                ReviewText
# 380818  At only 80 calories these are a great bang for...
# 21338   I sent for the tea, because I can't buy it in ...
# 368711  I absolutely love these chocolate bars! They c...
# 141202  I have been drinking this Chamomile tea for th...
# 180881  My dogs do well on Wellness Simple Solutions; ...
# ...                                                   ...
# 150122  I think the ingredients in this food speak for...
# 295370  I have tried many k-cups and this one is by fa...
# 118004  My dogs had this chewed apart in the matter of...
# 303837  First of all, let me say that I LIKE the stuff...
# 1800    This tea is really quite good. It is a quality...
#
# [482941 rows x 2 columns]

# %% [markdown]
# ## 1.1.2. Cleaning y_train

# %%
y_train = clean_y(y_train)
y_train
# Out:
# 0         good
# 1         good
# 2         good
# 3         good
# 4         good
#           ...
# 482936     bad
# 482937    good
# 482938     bad
# 482939    good
# 482940    good
# Name: score, Length: 482941, dtype: object

# %% [markdown]
# ## 1.2 Preprocessing X_train

# %%
from tqdm import tqdm, tqdm_notebook

# %%
tqdm.pandas()

# %%
temp_df_1 = X_train['ReviewSummary'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_1.columns = ['revsum_clean_text_stem', 'revsum_text_length_stem']
# Out:
# 100%|█████████████████████████████████| 482941/482941 [01:52<00:00, 4288.44it/s]

# %%
temp_df_2 = X_train['ReviewText'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_2.columns = ['revtext_clean_text_stem', 'revtext_text_length_stem']
# Out:
# 100%|██████████████████████████████████| 482941/482941 [26:04<00:00, 308.68it/s]

# %%
temp_df = pd.concat([temp_df_1, temp_df_2], axis = 1)
temp_df
# Out:
#                                 revsum_clean_text_stem  \
# 380818                           great bang calor buck
# 21338                                          favorit
# 368711                                        new love
# 141202                               fine chamomil tea
# 180881                       well simpl solut dog food
# ...                                                ...
# 150122                sicken filler ingredi high price
# 295370                                     bold flavor
# 118004                  nylabon durabl dental dinosaur
# 303837  pretti damn good like wawa conveni store stuff
# 1800                                             tasti
#
#         revsum_text_length_stem  \
# 380818                        4
# 21338                         1
# 368711                        2
# 141202                        3
# 180881                        5
# ...                         ...
# 150122                        5
# 295370                        2
# 118004                        4
# 303837                        8
# 1800                          1
#
#                                   revtext_clean_text_stem  \
# 380818  calori great bang calor buck br low sugar low ...
# 21338      sent tea buy smaller town move glad back shelf
# 368711  absolut love chocol bar come nice wrap thin oz...
# 141202  drink chamomil tea past year late night need r...
# 180881  dog well well simpl solut great dog allergi pu...
# ...                                                   ...
# 150122  think ingredi food speak cheap filler byproduc...
# 295370  tri mani k cup one far favorit deep flavor wit...
# 118004  dog chew apart matter minut eat small part dog...
# 303837  first let say like stuff wawa machin look want...
# 1800    tea realli quit good qualiti black tea subtl c...
#
#         revtext_text_length_stem
# 380818                        30
# 21338                          9
# 368711                        97
# 141202                        16
# 180881                        12
# ...                          ...
# 150122                        35
# 295370                        12
# 118004                        11
# 303837                        36
# 1800                          40
#
# [482941 rows x 4 columns]

# %%
X_train.drop(columns= ['ReviewSummary', 'ReviewText'], inplace = True)

# %%
X_train = pd.concat([X_train, temp_df], axis = 1)
X_train
# Out:
#                                 revsum_clean_text_stem  \
# 380818                           great bang calor buck
# 21338                                          favorit
# 368711                                        new love
# 141202                               fine chamomil tea
# 180881                       well simpl solut dog food
# ...                                                ...
# 150122                sicken filler ingredi high price
# 295370                                     bold flavor
# 118004                  nylabon durabl dental dinosaur
# 303837  pretti damn good like wawa conveni store stuff
# 1800                                             tasti
#
#         revsum_text_length_stem  \
# 380818                        4
# 21338                         1
# 368711                        2
# 141202                        3
# 180881                        5
# ...                         ...
# 150122                        5
# 295370                        2
# 118004                        4
# 303837                        8
# 1800                          1
#
#                                   revtext_clean_text_stem  \
# 380818  calori great bang calor buck br low sugar low ...
# 21338      sent tea buy smaller town move glad back shelf
# 368711  absolut love chocol bar come nice wrap thin oz...
# 141202  drink chamomil tea past year late night need r...
# 180881  dog well well simpl solut great dog allergi pu...
# ...                                                   ...
# 150122  think ingredi food speak cheap filler byproduc...
# 295370  tri mani k cup one far favorit deep flavor wit...
# 118004  dog chew apart matter minut eat small part dog...
# 303837  first let say like stuff wawa machin look want...
# 1800    tea realli quit good qualiti black tea subtl c...
#
#         revtext_text_length_stem
# 380818                        30
# 21338                          9
# 368711                        97
# 141202                        16
# 180881                        12
# ...                          ...
# 150122                        35
# 295370                        12
# 118004                        11
# 303837                        36
# 1800                          40
#
# [482941 rows x 4 columns]

# %% [markdown]
# ## 1.3 Data Transformation

# %% [markdown]
# ### 1.3.1 Bag of Words approach

# %% [markdown]
# #### Just considering revtext and not revsum

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initializing the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.
vocab = CountVectorizer()

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.

X_train_bow = vocab.fit_transform(X_train['revtext_clean_text_stem'])

# %% [markdown]
# #### Unique Words

# %%
# We can look at unique words by using 'vocabulary_'

vocab.vocabulary_
# Out:
# {'calori': 8367,
#  'great': 24702,
#  'bang': 4412,
#  'calor': 8365,
#  'buck': 7551,
#  'br': 6897,
#  'low': 33691,
#  'sugar': 55540,
#  'fat': 20348,
#  'high': 26691,
#  'protein': 45483,
#  'tast': 56895,
#  'like': 32883,
#  'pepperoni': 42672,
#  'stick': 54753,
#  'without': 64011,
#  'mayb': 35208,
#  'littl': 33162,
#  'dri': 17078,
#  'side': 51887,
#  'bad': 4178,
#  'use': 61290,
#  'workout': 64323,
#  'sent': 50951,
#  'tea': 57054,
#  'buy': 8002,
#  'smaller': 52658,
#  'town': 58891,
#  'move': 37473,
#  'glad': 23765,
#  'back': 4112,
#  'shelf': 51393,
#  'absolut': 220,
#  'love': 33641,
#  'chocol': 10508,
#  'bar': 4457,
#  'come': 11830,
#  'nice': 38824,
#  'wrap': 64448,
#  'thin': 57848,
#  'oz': 41487,
#  'troubl': 59379,
#  'set': 51103,
#  'groov': 24981,
#  'pattern': 42243,
#  'make': 34342,
#  'easi': 17604,
#  'break': 7051,
#  'triangl': 59202,
#  'though': 57972,
#  'prefer': 44778,
#  'crack': 13197,
#  'open': 40615,
#  'eat': 17638,
#  'tini': 58301,
#  'piec': 43390,
#  'sweet': 56221,
#  'milk': 36281,
#  'overli': 41303,
#  'probabl': 45156,
#  'thank': 57585,
#  'salt': 49589,
#  'almond': 1609,
#  'fraction': 21999,
#  'chew': 10140,
#  'crunch': 13657,
#  'let': 32630,
#  'melt': 35668,
#  'mouth': 37457,
#  'packag': 41537,
#  'say': 50044,
#  'cacao': 8113,
#  'ingredi': 28829,
#  'includ': 28478,
#  'cocoa': 11469,
#  'butter': 7934,
#  'nonfat': 39132,
#  'safflow': 49436,
#  'oil': 40219,
#  'non': 39099,
#  'gmo': 24007,
#  'soy': 53555,
#  'lecithin': 32433,
#  'etc': 19179,
#  'gluten': 23953,
#  'free': 22151,
#  'one': 40436,
#  'serv': 51058,
#  'half': 25590,
#  'contain': 12472,
#  'carb': 8803,
#  'go': 24029,
#  'huh': 27588,
#  'receiv': 47087,
#  'end': 18460,
#  'octob': 40014,
#  'best': 5400,
#  'well': 63210,
#  'see': 50712,
#  'last': 32164,
#  'long': 33408,
#  'drink': 17098,
#  'chamomil': 9718,
#  'past': 42144,
#  'year': 64856,
#  'late': 32176,
#  'night': 38883,
#  'need': 38465,
#  'relax': 47683,
#  'caffein': 8185,
#  'twine': 59768,
#  'excel': 19557,
#  'dog': 16596,
#  'simpl': 52089,
#  'solut': 53207,
#  'allergi': 1529,
#  'purchas': 45872,
#  'amazon': 1878,
#  'reliabl': 47705,
#  'treat': 59116,
#  'hard': 25841,
#  'appar': 2696,
#  'tasti': 56921,
#  'cat': 9184,
#  'anyth': 2559,
#  'alway': 1790,
#  'sushi': 56076,
#  'rice': 48414,
#  'brand': 6959,
#  'kind': 31136,
#  'wash': 62869,
#  'howev': 27455,
#  'suggest': 55575,
#  'anyway': 2569,
#  'version': 61957,
#  'shin': 51499,
#  'favorit': 20423,
#  'junk': 30449,
#  'food': 21674,
#  'fix': 21113,
#  'think': 57860,
#  'big': 5612,
#  'bag': 4206,
#  'larg': 32115,
#  'mushroom': 37855,
#  'flake': 21164,
#  'green': 24750,
#  'onion': 40470,
#  'also': 1697,
#  'larger': 32120,
#  'fresher': 22242,
#  'look': 33456,
#  'noodl': 39201,
#  'slightli': 52513,
#  'thinner': 57877,
#  'potenti': 44500,
#  'less': 32617,
#  'soggier': 53128,
#  'size': 52268,
#  'much': 37584,
#  'better': 5445,
#  'way': 63001,
#  'ramen': 46592,
#  'cheaper': 9910,
#  'sometim': 53269,
#  'inconveni': 28511,
#  'bother': 6716,
#  'alon': 1640,
#  'want': 62788,
#  'wast': 62895,
#  'rest': 48108,
#  'especi': 19060,
#  'put': 45999,
#  'egg': 17960,
#  'veggi': 61755,
#  'someon': 53241,
#  'els': 18224,
#  'peopl': 42615,
#  'sinc': 52123,
#  'sens': 50912,
#  'econom': 17749,
#  'math': 35111,
#  'even': 19335,
#  'expens': 19755,
#  'cost': 12942,
#  'per': 42698,
#  'save': 50000,
#  'money': 37051,
#  'rather': 46743,
#  'plu': 43916,
#  'reheat': 47597,
#  'flush': 21523,
#  'toilet': 58537,
#  'finish': 20956,
#  'sausag': 49981,
#  'wish': 63964,
#  'small': 52657,
#  'option': 40701,
#  'american': 1946,
#  'keurig': 30978,
#  'done': 16724,
#  'bit': 5878,
#  'experi': 19766,
#  'differ': 15789,
#  'varieti': 61603,
#  'coffe': 11543,
#  'avail': 3816,
#  'enjoy': 18605,
#  'newman': 38734,
#  'product': 45270,
#  'caught': 9289,
#  'eye': 19959,
#  'disappoint': 16081,
#  'sure': 55977,
#  'came': 8409,
#  'extra': 19897,
#  'bold': 6437,
#  'name': 38127,
#  'found': 21944,
#  'rel': 47669,
#  'weak': 63033,
#  'coupl': 13075,
#  'two': 59812,
#  'guest': 25204,
#  'might': 36209,
#  'weaker': 63035,
#  'smoother': 52794,
#  'blend': 6106,
#  'gave': 23146,
#  'away': 3917,
#  'flavor': 21270,
#  'robust': 48747,
#  'grandmoth': 24536,
#  'lipton': 33064,
#  'fragrant': 22011,
#  'good': 24193,
#  'whether': 63473,
#  'hot': 27349,
#  'ice': 27965,
#  'recommend': 47194,
#  'pleasant': 43835,
#  'chang': 9752,
#  'usual': 61343,
#  'orang': 40726,
#  'peko': 42516,
#  'quick': 46286,
#  'meat': 35421,
#  'eater': 17646,
#  'lunch': 33858,
#  'childhood': 10264,
#  'cruelti': 13635,
#  'first': 21044,
#  'start': 54512,
#  'starbuck': 54463,
#  'box': 6851,
#  'delici': 14970,
#  'nutriti': 39688,
#  'price': 45025,
#  'fresh': 22238,
#  'follow': 21635,
#  'heart': 26236,
#  'natur': 38291,
#  'store': 54938,
#  'cal': 8250,
#  'notic': 39352,
#  'chunk': 10791,
#  'black': 5948,
#  'particl': 42070,
#  'went': 63249,
#  'onlin': 40473,
#  'complain': 12002,
#  'chip': 10343,
#  'tooth': 58674,
#  'substanc': 55390,
#  'pre': 44688,
#  'preemptiv': 44765,
#  'pulver': 45762,
#  'mortar': 37316,
#  'pestl': 42972,
#  'ever': 19352,
#  'beach': 4806,
#  'get': 23422,
#  'sand': 49707,
#  'grind': 24885,
#  'teeth': 57199,
#  'return': 48235,
#  'today': 58481,
#  'never': 38698,
#  'manufactur': 34698,
#  'himalayan': 26780,
#  'tri': 59196,
#  'celtic': 9494,
#  'time': 58246,
#  'fli': 21366,
#  'moth': 37370,
#  'hous': 27409,
#  'trap': 59055,
#  'still': 54790,
#  'catch': 9210,
#  'clap': 11073,
#  'hand': 25689,
#  'far': 20262,
#  'total': 58817,
#  'sorri': 53440,
#  'sell': 50816,
#  'paper': 41860,
#  'fold': 21613,
#  'strip': 55124,
#  'europ': 19284,
#  'effect': 17913,
#  'sold': 53161,
#  'dispens': 16305,
#  'pill': 43458,
#  'pet': 42975,
#  'pocket': 43987,
#  'daughter': 14389,
#  'almost': 1620,
#  'old': 40286,
#  'breastfeed': 7093,
#  'emerg': 18292,
#  'breast': 7089,
#  'surgeri': 55998,
#  'month': 37158,
#  'take': 56607,
#  'formula': 21865,
#  'chose': 10671,
#  'earth': 17572,
#  'seem': 50735,
#  'toler': 58557,
#  'fine': 20925,
#  'issu': 29564,
#  'imagin': 28165,
#  'shock': 51619,
#  'read': 46879,
#  'organ': 40814,
#  'consum': 12452,
#  'email': 18245,
#  'newslett': 38750,
#  'inform': 28780,
#  'genet': 23287,
#  'engin': 18562,
#  'neutraceut': 38684,
#  'dha': 15569,
#  'horizon': 27262,
#  'anger': 2258,
#  'ask': 3370,
#  'compon': 12040,
#  'clearli': 11150,
#  'carri': 9034,
#  'label': 31842,
#  'thing': 57853,
#  'convent': 12606,
#  'would': 64396,
#  'pick': 43338,
#  'regular': 47574,
#  'infant': 28724,
#  'day': 14434,
#  'mislead': 36595,
#  'anywher': 2576,
#  'near': 38397,
#  'develop': 15499,
#  'child': 10258,
#  'law': 32284,
#  'pass': 42120,
#  'guess': 25197,
#  'trust': 59459,
#  'buyer': 8005,
#  'bewar': 5497,
#  'lavazza': 32266,
#  'everi': 19370,
#  'pot': 44476,
#  'brew': 7160,
#  'smooth': 52790,
#  'strong': 55146,
#  'stash': 54534,
#  'lemon': 32535,
#  'ginger': 23650,
#  'herbal': 26508,
#  'basic': 4630,
#  'strongli': 55152,
#  'full': 22650,
#  'oddli': 40035,
#  'commerci': 11890,
#  'highli': 26709,
#  'process': 45218,
#  'made': 34142,
#  'artifici': 3239,
#  'certainli': 9577,
#  'picki': 43348,
#  'herb': 26505,
#  'someth': 53259,
#  'introduct': 29289,
#  'world': 64335,
#  'teasan': 57116,
#  'decaffein': 14570,
#  'beverag': 5482,
#  'subtl': 55427,
#  'true': 59414,
#  'pure': 45895,
#  'discern': 16118,
#  'complex': 12023,
#  'definit': 14813,
#  'numi': 39528,
#  'yogi': 65037,
#  'tradit': 58958,
#  'medicin': 35488,
#  'line': 32992,
#  'wonder': 64156,
#  'root': 48935,
#  'lemongrass': 32545,
#  'hibiscu': 26648,
#  'citric': 10999,
#  'acid': 427,
#  'unfortun': 60560,
#  'noth': 39337,
#  'special': 53724,
#  'golean': 24152,
#  'begun': 5067,
#  'discov': 16168,
#  'amaz': 1858,
#  'coconut': 11494,
#  'incred': 28532,
#  'health': 26180,
#  'benefit': 5230,
#  'googl': 24243,
#  'knew': 31349,
#  'virgin': 62252,
#  'comparison': 11965,
#  'sign': 51948,
#  'subscrib': 55358,
#  'smell': 52704,
#  'daili': 14179,
#  'face': 20022,
#  'lotion': 33584,
#  'skin': 52344,
#  'diagnos': 15605,
#  'eczema': 17787,
#  'instead': 29058,
#  'prescript': 44900,
#  'fantast': 20242,
#  'cook': 12653,
#  'bake': 4273,
#  'substitut': 55406,
#  'know': 31390,
#  'veget': 61735,
#  'outweigh': 41171,
#  'glass': 23784,
#  'jar': 29887,
#  'groceri': 24949,
#  'ship': 51515,
#  'plastic': 43767,
#  'expos': 19826,
#  'toxin': 58906,
#  'certaintli': 9582,
#  'enough': 18635,
#  'cup': 13881,
#  'nearli': 38403,
#  'qualiti': 46167,
#  'ita': 29581,
#  'thick': 57817,
#  'instant': 29048,
#  'everyday': 19394,
#  'add': 561,
#  'appl': 2742,
#  'secondari': 50677,
#  'ferment': 20628,
#  'cider': 10842,
#  'note': 39328,
#  'tsp': 59507,
#  'gallon': 22919,
#  'everyon': 19413,
#  'must': 37882,
#  'contribut': 12568,
#  'broadli': 7313,
#  'posit': 44423,
#  'feedback': 20510,
#  'continu': 12529,
#  'amount': 2046,
#  'state': 54542,
#  'work': 64304,
#  'pretti': 44972,
#  'ok': 40253,
#  'bye': 8045,
#  'gf': 23456,
#  'cake': 8236,
#  'mix': 36702,
#  'mani': 34614,
#  'fashion': 20323,
#  'moist': 36911,
#  'rich': 48429,
#  'bias': 5567,
#  'irish': 29427,
#  'overal': 41207,
#  'everyth': 19420,
#  'ireland': 29416,
#  'whiskey': 63556,
#  'beer': 5014,
#  'oatmeal': 39829,
#  'cours': 13090,
#  'healthiest': 26196,
#  'three': 58005,
#  'oprah': 40687,
#  'steel': 54626,
#  'cut': 14004,
#  'oat': 39816,
#  'listen': 33112,
#  'appear': 2713,
#  'right': 48520,
#  'target': 56815,
#  'cholesterol': 10588,
#  'test': 57476,
#  'doctor': 16573,
#  'medic': 35479,
#  'could': 13014,
#  'anoth': 2388,
#  'week': 63113,
#  'diet': 15758,
#  'breakfast': 7064,
#  'morn': 37278,
#  'said': 49472,
#  'hey': 26613,
#  'whatev': 63370,
#  'keep': 30807,
#  'number': 39518,
#  'wrong': 64502,
#  'miracl': 36509,
#  'healthi': 26194,
#  'choic': 10561,
#  'leav': 32409,
#  'fill': 20867,
#  'cereal': 9547,
#  'bacon': 4165,
#  'fairli': 20099,
#  'bland': 6017,
#  'expect': 19731,
#  'mine': 36383,
#  'cinnamon': 10914,
#  'raisin': 46549,
#  'either': 18041,
#  'honey': 27139,
#  'sweetner': 56258,
#  'ad': 540,
#  'normal': 39258,
#  'place': 43700,
#  'local': 33304,
#  'club': 11316,
#  'unlik': 60727,
#  'supermarket': 55832,
#  'realli': 46928,
#  'thoroughli': 57960,
#  'real': 46904,
#  'husband': 27731,
#  'bought': 6767,
#  'travel': 59082,
#  'gift': 23581,
#  'howdi': 27449,
#  'item': 29614,
#  'fajita': 20111,
#  'detect': 15456,
#  'scent': 50165,
#  'sigh': 51937,
#  'chili': 10278,
#  'chicken': 10203,
#  'soup': 53495,
#  'problem': 45185,
#  'powder': 44575,
#  'carrot': 9051,
#  'kidney': 31073,
#  'bean': 4831,
#  'starchi': 54477,
#  'gritti': 24924,
#  'southwestern': 53541,
#  'pinto': 43560,
#  'decent': 14612,
#  'tex': 57517,
#  'mex': 35991,
#  'joint': 30227,
#  'rate': 46740,
#  'cuz': 14033,
#  'care': 8892,
#  'lee': 32442,
#  'campbel': 8441,
#  'happi': 25795,
#  'order': 40759,
#  'can': 8463,
#  'bowl': 6841,
#  'pasta': 42145,
#  'impress': 28350,
#  'quickli': 46297,
#  'arriv': 3173,
#  'friend': 22303,
#  'worri': 64351,
#  'bouquet': 6807,
#  'falcon': 20124,
#  'farm': 20286,
#  'review': 48284,
#  'flower': 21474,
#  'exactli': 19518,
#  'deliv': 15055,
#  'told': 58553,
#  'perfectli': 42752,
#  'condit': 12178,
#  'beauti': 4893,
#  'point': 44037,
#  'facon': 20039,
#  'chai': 9667,
#  'perfect': 42745,
#  'fall': 20131,
#  'weather': 63062,
#  'warehous': 62813,
#  'dentist': 15206,
#  'xylitol': 64732,
#  'altern': 1717,
#  'fluorid': 21517,
#  'base': 4616,
#  'minut': 36493,
#  'worth': 64366,
#  'caviti': 9344,
#  'six': 52256,
#  'given': 23735,
#  'replac': 47897,
#  'feroci': 20637,
#  'attack': 3627,
#  'begin': 5058,
#  'shortli': 51688,
#  'afterward': 968,
#  'search': 50598,
#  'tazo': 57003,
#  'celesti': 9451,
#  'season': 50623,
#  'okay': 40259,
#  'train': 58980,
#  'revolut': 48304,
#  'bombay': 6487,
#  'alto': 1753,
#  'eco': 17730,
#  'ceylon': 9621,
#  'kashmiri': 30682,
#  'tetley': 57497,
#  'surprisingli': 56029,
#  'looos': 33521,
#  'direct': 16034,
#  'seller': 50821,
#  'golden': 24123,
#  'spicey': 53852,
#  'hold': 27005,
#  'plain': 43716,
#  'splenda': 53952,
#  'bite': 5883,
#  'overpow': 41325,
#  'simpli': 52099,
#  'boot': 6607,
#  'masala': 35014,
#  'balanc': 4302,
#  'spice': 53844,
#  'invigor': 29341,
#  'subject': 55327,
#  'feed': 20509,
#  'famili': 20175,
#  'four': 21956,
#  'door': 16785,
#  'wheat': 63399,
#  'spoil': 53980,
#  'michigan': 36080,
#  'experienc': 19770,
#  'forc': 21759,
#  'singl': 52147,
#  'colombian': 11740,
#  'thought': 57975,
#  'give': 23733,
#  'result': 48160,
#  'ground': 25001,
#  'star': 54452,
#  'cooki': 12661,
#  'germani': 23393,
#  'find': 20917,
#  'us': 61276,
#  'amus': 2083,
#  'close': 11275,
#  'relat': 47676,
#  'pecan': 42413,
#  'sandi': 49717,
#  'richer': 48434,
#  'moister': 36913,
#  'possibl': 44438,
#  'alreadi': 1682,
#  'bigger': 5630,
#  'immedi': 28218,
#  'complet': 12017,
#  'extrem': 19925,
#  'whiska': 63553,
#  'tuna': 59609,
#  'pouch': 44530,
#  'content': 12502,
#  'life': 32795,
#  'switch': 56330,
#  'english': 18573,
#  'bulldog': 7698,
#  'rash': 46711,
#  'rid': 48464,
#  'person': 42906,
#  'caus': 9299,
#  'tell': 57244,
#  'quit': 46365,
#  'harder': 25851,
#  'floor': 21425,
#  'wait': 62671,
#  'happen': 25792,
#  'pack': 41530,
#  'empti': 18381,
#  'decreas': 14671,
#  'valu': 61512,
#  'lot': 33582,
#  'eaten': 17643,
#  'potato': 44487,
#  'least': 32401,
#  'healthier': 26195,
#  'second': 50676,
#  'fast': 20333,
#  'mother': 37373,
#  'licoric': 32760,
#  'thrill': 58025,
#  'share': 51290,
#  'ago': 1048,
#  'display': 16318,
#  'next': 38772,
#  'rememb': 47753,
#  'call': 8326,
#  'excit': 19605,
#  'saw': 50035,
#  'later': 32182,
#  'abl': 124,
#  'around': 3143,
#  'auto': 3763,
#  'often': 40162,
#  'kashi': 30679,
#  'requisit': 47974,
#  'dr': 16974,
#  'pepper': 42655,
#  'lost': 33581,
#  'pound': 44550,
#  'earlier': 17559,
#  'novemb': 39408,
#  'starv': 54528,
#  'serious': 51035,
#  'hungri': 27682,
#  'claim': 11048,
#  'evalu': 19309,
#  'anyon': 2547,
#  'anim': 2298,
#  'tortur': 58791,
#  'prove': 45530,
#  'allerg': 1522,
#  'dairi': 14187,
#  'other': 40998,
#  'versatil': 61952,
#  'water': 62921,
#  'part': 42055,
#  'pour': 44561,
#  'pancak': 41752,
#  'ziploc': 65545,
#  'battl': 4705,
#  'weight': 63154,
#  'school': 50273,
#  'final': 20906,
#  'lose': 33573,
#  'feel': 20518,
#  'depriv': 15259,
#  'tribest': 59217,
#  'blender': 6108,
#  'href': 27490,
#  'http': 27525,
#  'bolder': 6438,
#  'earn': 17566,
#  'five': 21108,
#  'hall': 25604,
#  'frame': 22024,
#  'polit': 44076,
#  'correct': 12875,
#  'age': 1001,
#  'live': 33174,
#  'skinless': 52348,
#  'boneless': 6512,
#  'sardin': 49822,
#  'invad': 29310,
#  'shelv': 51413,
#  'promis': 45362,
#  'appropri': 2822,
#  'civil': 11024,
#  'elsewher': 18229,
#  'anthesi': 2425,
#  'refer': 47411,
#  'skinni': 52351,
#  'boney': 6516,
#  'may': 35203,
#  'sound': 53487,
#  'rough': 49044,
#  'edg': 17813,
#  'heck': 26315,
#  'disclos': 16127,
#  'em': 18242,
#  'plump': 43931,
#  'pilchard': 43451,
#  'among': 2021,
#  'gener': 23274,
#  'oper': 40624,
#  'premis': 44840,
#  'portugues': 44406,
#  'superior': 55821,
#  'increasingli': 28531,
#  'gourmet': 24387,
#  'forgot': 21825,
#  'across': 490,
#  'spanish': 53646,
#  'junctur': 30439,
#  'knowledg': 31396,
#  'geographi': 23350,
#  'stood': 54912,
#  'stead': 54586,
#  'realiz': 46923,
#  'atlant': 3591,
#  'portug': 44405,
#  'contigu': 12520,
#  'spain': 53625,
#  'fish': 21055,
#  'boundari': 6800,
#  'therefor': 57744,
#  'third': 57885,
#  'combin': 11817,
#  'oliv': 40331,
#  'suspicion': 56090,
#  'arous': 3150,
#  'subsequ': 55376,
#  'research': 48009,
#  'matter': 35144,
#  'uncov': 60264,
#  'colleg': 11712,
#  'chest': 10128,
#  'physician': 43281,
#  'omega': 40378,
#  'fatti': 20379,
#  'benefici': 5226,
#  'immers': 28241,
#  'addit': 586,
#  'slice': 52493,
#  'tin': 58283,
#  'intak': 29104,
#  'vitamin': 62326,
#  'chase': 9860,
#  'perform': 42765,
#  'dissect': 16375,
#  'prior': 45116,
#  'indulg': 28666,
#  'peach': 42359,
#  'sweetend': 56231,
#  'pie': 43387,
#  'dont': 16751,
#  'shove': 51720,
#  'hasnt': 25963,
#  'pumpkin': 45783,
#  'die': 15737,
#  'pleas': 43834,
#  'creamer': 13344,
#  'latt': 32208,
#  'stock': 54848,
#  'babi': 4056,
#  'gassi': 23084,
#  'longer': 33418,
#  'com': 11795,
#  'variou': 61607,
#  'kcup': 30770,
#  'mostli': 37360,
#  'vanila': 61547,
#  'hazelnut': 26092,
#  'choclat': 10473,
#  'origin': 40862,
#  'garden': 23011,
#  'christma': 10722,
#  'dilig': 15907,
#  'took': 58651,
#  'grew': 24829,
#  'felt': 20574,
#  'steer': 54641,
#  'clear': 11140,
#  'machin': 34076,
#  'mild': 36255,
#  'alcohol': 1359,
#  'light': 32831,
#  'color': 11750,
#  'shell': 51399,
#  'dark': 14321,
#  'brown': 7399,
#  'pictur': 43376,
#  'zip': 65538,
#  'lock': 33315,
#  'vacuum': 61437,
#  'seal': 50568,
#  'foil': 21603,
#  'protect': 45479,
#  'sunlight': 55714,
#  'expir': 19790,
#  'date': 14373,
#  'idea': 28012,
#  'stuf': 55211,
#  'grape': 24589,
#  'fabul': 20013,
#  'via': 62047,
#  'chill': 10284,
#  'salti': 49597,
#  'spici': 53854,
#  'firm': 21031,
#  'apart': 2616,
#  'run': 49229,
#  'tightli': 58196,
#  'pull': 45740,
#  'tab': 56488,
#  'offer': 40113,
#  'purpos': 45956,
#  'americano': 1951,
#  'influenst': 28768,
#  'pleasantli': 43836,
#  'surpris': 56026,
#  'textur': 57534,
#  'truli': 59443,
#  'soft': 53108,
#  'devour': 15539,
#  'whet': 63470,
#  'defiantli': 14777,
#  'cannot': 8584,
#  'believ': 5141,
#  'italian': 29591,
#  'cashew': 9118,
#  'togeth': 58526,
#  'roast': 48707,
#  'oi': 40213,
#  'new': 38708,
#  'loos': 33529,
#  'profession': 45296,
#  'leg': 32467,
#  'crapm': 13277,
#  'help': 26436,
#  'taken': 56610,
#  'dose': 16846,
#  'grass': 24619,
#  'bodi': 6379,
#  'energ': 18523,
#  'syrup': 56453,
#  'vs': 62528,
#  'corn': 12810,
#  'nutrit': 39686,
#  'seriou': 51032,
#  'barilla': 4526,
#  'folger': 21620,
#  'french': 22210,
#  'concern': 12121,
#  'decemb': 14608,
#  'bulk': 7690,
#  'interest': 29160,
#  'rock': 48764,
#  'dish': 16234,
#  'turn': 59672,
#  'tend': 57313,
#  'lower': 33701,
#  'rajma': 46566,
#  'okra': 40274,
#  'bhindi': 5537,
#  'downsid': 16938,
#  'tag': 56552,
#  'mana': 34526,
#  'potion': 44508,
#  'whim': 63514,
#  'topic': 58706,
#  'weekend': 63116,
#  'figur': 20835,
#  'plan': 43727,
#  'wow': 64425,
#  'marathon': 34764,
#  'bottl': 6733,
#  'aw': 3905,
#  'red': 47267,
#  'bull': 7695,
#  'gross': 24987,
#  'death': 14531,
#  'knight': 31357,
#  'kept': 30902,
#  'pinch': 43503,
#  'alittl': 1472,
#  'whimsi': 63519,
#  'fun': 22671,
#  'mt': 37566,
#  'dew': 15543,
#  'broccoli': 7319,
#  'pea': 42349,
#  'spinach': 53886,
#  'unless': 60722,
#  'packabl': 41533,
#  'snack': 52828,
#  'parent': 41968,
#  'younger': 65141,
#  'children': 10272,
#  ...}

# %%
print("Total unique words", len(vocab.vocabulary_))

print("Type of train features:", type(X_train_bow))

print("Shape of input data:", X_train_bow.shape)
# Out:
# Total unique words 65679
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>
# Shape of input data: (482941, 65679)

# %% [markdown]
# ## 2.1.1. Cleaning X_test

# %%
# %%time

X_test = clean_X(X_test)
X_test
# Out:
# CPU times: user 16.3 ms, sys: 172 ms, total: 188 ms
# Wall time: 212 ms
#                                             ReviewSummary  \
# 529445                     One of the best breakfast teas
# 271152                               Grilled is the best!
# 415447          Wolfgang Puck Coffee, Vienna Coffee House
# 333254                        Everything a Cola should be
# 71360   Like Something You might find for sale at a fo...
# ...                                                   ...
# 152671                              Excellent Oatmeal Bar
# 435958                              Almond Anise Biscotti
# 170682                             they just dont like em
# 391149                                        great snack
# 447995                                helps me get drowsy
#
#                                                ReviewText
# 529445  Yorkshire Gold is one of my favorite breakfast...
# 271152  My cat loves the Fancy Feast grilled style.  H...
# 415447  great tasting coffee. strong, but not obnoxiou...
# 333254  This is the best Cola I have ever tasted.  I f...
# 71360   I, too, first tasted this at a "caf&eacute; ne...
# ...                                                   ...
# 152671  These Bars are the best that I have ever had. ...
# 435958  Celiac so this is a real treat in the morning ...
# 170682  only 1 of my 2 cats have shown any interest at...
# 391149  This product is a healthy snack during my work...
# 447995  This is a 2 fold product and you must be aware...
#
# [85226 rows x 2 columns]

# %% [markdown]
# ## 2.1.2. Cleaning y_teset

# %%
y_test = clean_y(y_test)
y_test
# Out:
# 0        good
# 1        good
# 2        good
# 3        good
# 4         bad
#          ...
# 85221    good
# 85222    good
# 85223     bad
# 85224    good
# 85225    good
# Name: score, Length: 85226, dtype: object

# %% [markdown]
# ## 2.2. Preprocessing X_test

# %%
temp_df_1 = X_test['ReviewSummary'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_1.columns = ['revsum_clean_text_stem', 'revsum_text_length_stem']
# Out:
# 100%|███████████████████████████████████| 85226/85226 [00:21<00:00, 4044.85it/s]

# %%
temp_df_2 = X_test['ReviewText'].progress_apply(lambda x: preprocess(x, 'stem'))
temp_df_2.columns = ['revtext_clean_text_stem', 'revtext_text_length_stem']
# Out:
# 100%|████████████████████████████████████| 85226/85226 [05:39<00:00, 250.85it/s]

# %%
temp_df = pd.concat([temp_df_1, temp_df_2], axis = 1)
temp_df
# Out:
#                                    revsum_clean_text_stem  \
# 529445                             one best breakfast tea
# 271152                                         grill best
# 415447              wolfgang puck coffe vienna coffe hous
# 333254                                       everyth cola
# 71360   like someth might find sale four year old juic...
# ...                                                   ...
# 152671                                  excel oatmeal bar
# 435958                               almond anis biscotti
# 170682                                       dont like em
# 391149                                        great snack
# 447995                                    help get drowsi
#
#         revsum_text_length_stem  \
# 529445                        4
# 271152                        2
# 415447                        6
# 333254                        2
# 71360                        10
# ...                         ...
# 152671                        3
# 435958                        3
# 170682                        3
# 391149                        2
# 447995                        3
#
#                                   revtext_clean_text_stem  \
# 529445  yorkshir gold one favorit breakfast tea like t...
# 271152  cat love fanci feast grill style favorit flavo...
# 415447  great tast coffe strong obnoxi strong nasti af...
# 333254  best cola ever tast first tri decid stop buy p...
# 71360   first tast caf eacut next moulin roug pari deg...
# ...                                                   ...
# 152671  bar best ever sweet great textur even realiz e...
# 435958                   celiac real treat morn cup coffe
# 170682  cat shown interest mylar toy she attract crink...
# 391149  product healthi snack workday kid homework tim...
# 447995  fold product must awar great make drowsi bedti...
#
#         revtext_text_length_stem
# 529445                        66
# 271152                        37
# 415447                        14
# 333254                       101
# 71360                        192
# ...                          ...
# 152671                        17
# 435958                         6
# 170682                        38
# 391149                        15
# 447995                        37
#
# [85226 rows x 4 columns]

# %%
X_test.drop(columns= ['ReviewSummary', 'ReviewText'], inplace = True)

# %%
X_test = pd.concat([X_test, temp_df], axis = 1)
X_test
# Out:
#                                    revsum_clean_text_stem  \
# 529445                             one best breakfast tea
# 271152                                         grill best
# 415447              wolfgang puck coffe vienna coffe hous
# 333254                                       everyth cola
# 71360   like someth might find sale four year old juic...
# ...                                                   ...
# 152671                                  excel oatmeal bar
# 435958                               almond anis biscotti
# 170682                                       dont like em
# 391149                                        great snack
# 447995                                    help get drowsi
#
#         revsum_text_length_stem  \
# 529445                        4
# 271152                        2
# 415447                        6
# 333254                        2
# 71360                        10
# ...                         ...
# 152671                        3
# 435958                        3
# 170682                        3
# 391149                        2
# 447995                        3
#
#                                   revtext_clean_text_stem  \
# 529445  yorkshir gold one favorit breakfast tea like t...
# 271152  cat love fanci feast grill style favorit flavo...
# 415447  great tast coffe strong obnoxi strong nasti af...
# 333254  best cola ever tast first tri decid stop buy p...
# 71360   first tast caf eacut next moulin roug pari deg...
# ...                                                   ...
# 152671  bar best ever sweet great textur even realiz e...
# 435958                   celiac real treat morn cup coffe
# 170682  cat shown interest mylar toy she attract crink...
# 391149  product healthi snack workday kid homework tim...
# 447995  fold product must awar great make drowsi bedti...
#
#         revtext_text_length_stem
# 529445                        66
# 271152                        37
# 415447                        14
# 333254                       101
# 71360                        192
# ...                          ...
# 152671                        17
# 435958                         6
# 170682                        38
# 391149                        15
# 447995                        37
#
# [85226 rows x 4 columns]

# %% [markdown]
# ## 2.3 Data Transformation

# %% [markdown]
# ### Bag of Words

# %% [markdown]
# #### Just considering revtext and not revsum

# %%
X_test_bow = vocab.transform(X_test['revtext_clean_text_stem'])

# %%
print("Total unique words", len(vocab.vocabulary_))

print("Type of train features:", type(X_test_bow))
# Out:
# Total unique words 65679
# Type of train features: <class 'scipy.sparse._csr.csr_matrix'>

# %% [markdown]
# # 3. Model

# %% [markdown]
# ## Logistic Regression

# %%
X_train.shape
# Out:
# (482941, 4)

# %%
X_train_bow.shape
# Out:
# (482941, 65679)

# %%
len(y_train)
# Out:
# 482941

# %%
# %%time

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_bow, y_train)
# Out:
# CPU times: user 13.8 s, sys: 1.23 s, total: 15 s
# Wall time: 14.3 s
# /Users/r.shahukaru/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))
# Out:
# 0.8632459578063032
#               precision    recall  f1-score   support
#
#          bad       0.75      0.64      0.69     12300
#         good       0.89      0.97      0.93     66534
#      neutral       0.53      0.20      0.29      6392
#
#     accuracy                           0.86     85226
#    macro avg       0.72      0.60      0.64     85226
# weighted avg       0.84      0.86      0.85     85226

# %% [markdown]
# ## Decision Tree

# %%
# %%time

from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_bow, y_train)

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))

# %% [markdown]
# ## Random Forest

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier()
classifier.fit(X_train_bow, y_train)

# %%
y_test_pred = classifier.predict(X_test_bow)

# %%
from sklearn.metrics import accuracy_score, classification_report

print(accuracy_score(y_test, y_test_pred))

print(classification_report(y_test, y_test_pred))

# %%
X_test_bow

# %%
def preprocess_str(text):
    
    flag = 'stem'
    
    text = re.sub("n't", " not", text)
    
    #1. Removing special characters and digits
    sentence = re.sub("[^a-zA-Z]", " ", text)
    
    #2. Converting to lowercase
    sentence_1 = sentence.lower()
    
    #3. Tokenization (Word-level)
    tokens = sentence_1.split()
    
    #3.1. TextBlob- Correcting the spellings
    tokens_correct_spell = [str(TextBlob(token)) for token in tokens]

    #4. Removing stopwords
    clean_tokens = [token for token in tokens_correct_spell if token not in stopwords.words("english")]

    #5. lemmatization
    if(flag == 'stem'):
        clean_tokens_final = [stemmer.stem(word) for word in clean_tokens]
    else:
        clean_tokens_final = [lemmatizer.lemmatize(word) for word in clean_tokens]
    
    return pd.Series([" ".join(clean_tokens_final)])

# %%
preprocess_str("Very good burger.")

# %%
preprocess_str("Hated the food. Wouldn't recommend it.")

# %%
a = vocab.transform(preprocess_str("Very good burger."))
a

# %%
a[0]

# %%
classifier.predict(a)[0]

# %%
text = str(input("Please input a review: "))

a = vocab.transform(preprocess_str(text))

print()
print(classifier.predict(a)[0])
